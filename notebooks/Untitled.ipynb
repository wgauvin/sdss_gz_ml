# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import uncertainties as unc
import uncertainties.unumpy as unp

# %%
x = unc.ufloat(0.7147, 0.0044)
y = unc.ufloat(0.8961, 0.0068)

# %%
x, y
# Out:
# (0.7147+/-0.0044, 0.8961+/-0.0068)

# %%
z = x / y
z
# Out:
# 0.7975672357995759+/-0.007793583830234377

# %%
zlog = unp.log(x/ y)
zlog
# Out:
# array(-0.2261891396642407+/-0.009771695075238599, dtype=object)

# %%
import sdss_gz_data as sgd
# Out:
# /usr/local/Cellar/python/3.7.1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 216, got 192
#   return f(*args, **kwds)
# /usr/local/Cellar/python/3.7.1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 216, got 192
#   return f(*args, **kwds)
# /usr/local/Cellar/python/3.7.1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 216, got 192
#   return f(*args, **kwds)
# /usr/local/Cellar/python/3.7.1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
# ...

# %%
orig_data = sgd.load_data('data/astromonical_data.csv.gz')

# %%
orig_data = sgd.filter_data(orig_data)
# Out:
# Filtered out 3501 invalid records

# %%
orig_data.columns.T
# Out:
# Index(['objid', 'run', 'rerun', 'camcol', 'field', 'obj', 'ra', 'dec', 'clean',
#        'petroRad_u',
#        ...
#        'spiralclock', 'spiralanticlock', 'edgeon', 'dontknow', 'merger',
#        'debiased_elliptical', 'debiased_spiral', 'debiased_spiral_ind',
#        'debiased_elliptical_ind', 'debiased_uncertain_ind'],
#       dtype='object', length=156)

# %%
orig_data[['petroRad_u','petroRadErr_u']]
# Out:
#         petroRad_u  petroRadErr_u
# 0         5.890151       0.882720
# 1        10.085310       2.063329
# 2         4.053304       1.173847
# 3         7.729528       2.137992
# 4         3.649967       0.559047
# 5         2.207780       2.102091
# 6         1.833266       0.731723
# 7         3.023220       0.597911
# 8         4.015852       0.686633
# 9         3.896674       2.358055
# 10        7.200445       0.579469
# 11        8.844035       2.604113
# 12        5.405427       0.506181
# 13        2.969415   -1000.000000
# 14        3.199488       0.113995
# 15       10.977060       0.623555
# 16        5.752189       0.197392
# 17        2.518092       1.534888
# 18        8.475315       0.570724
# 19        2.949809       0.501329
# 20        6.374875       3.497056
# 21       11.111290       0.871556
# 22        8.342175       4.608613
# 23        4.494270       0.416915
# 24        6.938444       3.572425
# 25       68.319620   -1000.000000
# ...

# %%
petroRad_u = unp.uarray((orig_data['petroRad_u'].values, orig_data['petroRadErr_u'].values))
# Out:
# /Users/will/Development/Astronomy/proposal/ENV/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Obsolete: uarray() should now be called with two arguments. Code can be automatically updated with python -m uncertainties.1to2 -w ProgramDirectory.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# NegativeStdDev                            Traceback (most recent call last)
# <ipython-input-17-70ccb5d0dd51> in <module>
# ----> 1 petroRad_u = unp.uarray((orig_data['petroRad_u'].values, orig_data['petroRadErr_u'].values))
#
# ~/Development/Astronomy/proposal/ENV/lib/python3.7/site-packages/uncertainties/unumpy/core.py in uarray(nominal_values, std_devs)
#     289         # significant speed up:
#     290         lambda v, s: uncert_core.Variable(v, s), otypes=[object])
# --> 291         (nominal_values, std_devs))
#     292
# ...

# %%
orig_data[orig_data.petroRadErr_u > 0][['petroRad_u', 'petroRadErr_u']]
# Out:
#         petroRad_u  petroRadErr_u
# 0         5.890151       0.882720
# 1        10.085310       2.063329
# 2         4.053304       1.173847
# 3         7.729528       2.137992
# 4         3.649967       0.559047
# 5         2.207780       2.102091
# 6         1.833266       0.731723
# 7         3.023220       0.597911
# 8         4.015852       0.686633
# 9         3.896674       2.358055
# 10        7.200445       0.579469
# 11        8.844035       2.604113
# 12        5.405427       0.506181
# 14        3.199488       0.113995
# 15       10.977060       0.623555
# 16        5.752189       0.197392
# 17        2.518092       1.534888
# 18        8.475315       0.570724
# 19        2.949809       0.501329
# 20        6.374875       3.497056
# 21       11.111290       0.871556
# 22        8.342175       4.608613
# 23        4.494270       0.416915
# 24        6.938444       3.572425
# 26        4.822046       1.483841
# 27        3.296003       0.390153
# ...

# %%
orig_data.iloc[48985]
# Out:
# objid                      1237652934033801628
# run                                       1737
# rerun                                      301
# camcol                                       2
# field                                       78
# obj                                        412
# ra                                     318.862
# dec                                   -7.61668
# clean                                        1
# petroRad_u                             3.97802
# petroRad_g                             2.82828
# petroRad_r                             2.63907
# petroRad_i                             2.63854
# petroRad_z                             14.6527
# petroRadErr_u                         0.663371
# petroRadErr_g                         0.132872
# petroRadErr_r                        0.0767142
# petroRadErr_i                        0.0923227
# petroRadErr_z                          4.06238
# petroR50_u                             2.14585
# ...
